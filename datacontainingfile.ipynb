# %% [markdown]
# # Tabluar data pre-processong

# %% [markdown]
# # import all required libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random
np.random.seed(42)
random.seed(42)

# %% [markdown]
# # load data set

# %%
df=pd.read_csv('input_table.csv')

# %%
df.head(100)
# Out:
#      Invoice ID       City  Gender            Product line  Unit price  \
# 0   750-67-8428     Yangon  Female       Health and beauty       74.69
# 1   226-31-3081  Naypyitaw  Female  Electronic accessories       15.28
# 2   631-41-3108     Yangon    Male      Home and lifestyle       46.33
# 3   123-19-1176     Yangon    Male       Health and beauty       58.22
# 4   373-73-7910     Yangon    Male       Sports and travel       86.31
# ..          ...        ...     ...                     ...         ...
# 95  594-34-4444     Yangon    Male  Electronic accessories       97.16
# 96  766-85-7061   Mandalay    Male       Health and beauty       87.87
# 97  871-39-9221  Naypyitaw  Female  Electronic accessories       12.45
# 98  865-92-6136     Yangon    Male      Food and beverages       52.75
# 99  733-01-9107   Mandalay    Male      Home and lifestyle       82.70
#
#     Quantity     Total       Date      Payment  gross income  Rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Invoice ID    1000 non-null   object
#  1   City          1000 non-null   object
#  2   Gender        1000 non-null   object
#  3   Product line  1000 non-null   object
#  4   Unit price    1000 non-null   float64
#  5   Quantity      1000 non-null   int64
#  6   Total         1000 non-null   float64
#  7   Date          1000 non-null   object
#  8   Payment       1000 non-null   object
#  9   gross income  1000 non-null   float64
#  10  Rating        1000 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 86.1+ KB

# %%
df.isna().sum()
# Out:
# Invoice ID      0
# City            0
# Gender          0
# Product line    0
# Unit price      0
# Quantity        0
# Total           0
# Date            0
# Payment         0
# gross income    0
# Rating          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Invoice ID      0
# City            0
# Gender          0
# Product line    0
# Unit price      0
# Quantity        0
# Total           0
# Date            0
# Payment         0
# gross income    0
# Rating          0
# dtype: int64

# %%
df['Date'].unique()
# Out:
# array(['1/5/2019', '3/8/2019', '3/3/2019', '1/27/2019', '2/8/2019',
#        '3/25/2019', '2/25/2019', '2/24/2019', '1/10/2019', '2/20/2019',
#        '2/6/2019', '3/9/2019', '2/12/2019', '2/7/2019', '3/29/2019',
#        '1/15/2019', '3/11/2019', '1/1/2019', '1/21/2019', '3/5/2019',
#        '3/15/2019', '2/17/2019', '3/2/2019', '3/22/2019', '3/10/2019',
#        '1/25/2019', '1/28/2019', '1/7/2019', '3/23/2019', '1/17/2019',
#        '2/2/2019', '3/4/2019', '3/16/2019', '2/27/2019', '2/10/2019',
#        '3/19/2019', '2/3/2019', '3/7/2019', '2/28/2019', '3/27/2019',
#        '1/20/2019', '3/12/2019', '2/15/2019', '3/6/2019', '2/14/2019',
#        '3/13/2019', '1/24/2019', '1/6/2019', '2/11/2019', '1/22/2019',
#        '1/13/2019', '1/9/2019', '1/12/2019', '1/26/2019', '1/23/2019',
#        '2/23/2019', '1/2/2019', '2/9/2019', '3/26/2019', '3/1/2019',
#        '2/1/2019', '3/28/2019', '3/24/2019', '2/5/2019', '1/19/2019',
# ...

# %%
df["Total"] = df["Total"].round(2)

# %%
print(df)
# Out:
#       Invoice ID       City  Gender            Product line  Unit price  \
# 0    750-67-8428     Yangon  Female       Health and beauty       74.69
# 1    226-31-3081  Naypyitaw  Female  Electronic accessories       15.28
# 2    631-41-3108     Yangon    Male      Home and lifestyle       46.33
# 3    123-19-1176     Yangon    Male       Health and beauty       58.22
# 4    373-73-7910     Yangon    Male       Sports and travel       86.31
# ..           ...        ...     ...                     ...         ...
# 995  233-67-5758  Naypyitaw    Male       Health and beauty       40.35
# 996  303-96-2227   Mandalay  Female      Home and lifestyle       97.38
# 997  727-02-1313     Yangon    Male      Food and beverages       31.84
# 998  347-56-2442     Yangon    Male      Home and lifestyle       65.82
# 999  849-09-3807     Yangon  Female     Fashion accessories       88.34
#
#      Quantity    Total       Date      Payment  gross income  Rating
# ...

# %%
duplicate_count = df.duplicated(subset="Invoice ID").sum()
print(f"Number of duplicate Invoice IDs: {duplicate_count}")
# Out:
# Number of duplicate Invoice IDs: 0

# %%
df_cleaned = df.drop_duplicates(subset="Invoice ID", keep="first")

# %%
df["Calculated Gross Income"] = df["Total"] * 0.05

# %%
df["Calculated Gross Income"] = df["Calculated Gross Income"].round(2)

# %%
print(df)
# Out:
#       Invoice ID       City  Gender            Product line  Unit price  \
# 0    750-67-8428     Yangon  Female       Health and beauty       74.69
# 1    226-31-3081  Naypyitaw  Female  Electronic accessories       15.28
# 2    631-41-3108     Yangon    Male      Home and lifestyle       46.33
# 3    123-19-1176     Yangon    Male       Health and beauty       58.22
# 4    373-73-7910     Yangon    Male       Sports and travel       86.31
# ..           ...        ...     ...                     ...         ...
# 995  233-67-5758  Naypyitaw    Male       Health and beauty       40.35
# 996  303-96-2227   Mandalay  Female      Home and lifestyle       97.38
# 997  727-02-1313     Yangon    Male      Food and beverages       31.84
# 998  347-56-2442     Yangon    Male      Home and lifestyle       65.82
# 999  849-09-3807     Yangon  Female     Fashion accessories       88.34
#
#      Quantity    Total       Date      Payment  gross income  Rating  \
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
df["Date"] = df["Date"].dt.strftime("%Y-%m-%d")
print(df)
# Out:
#       Invoice ID       City  Gender            Product line  Unit price  \
# 0    750-67-8428     Yangon  Female       Health and beauty       74.69
# 1    226-31-3081  Naypyitaw  Female  Electronic accessories       15.28
# 2    631-41-3108     Yangon    Male      Home and lifestyle       46.33
# 3    123-19-1176     Yangon    Male       Health and beauty       58.22
# 4    373-73-7910     Yangon    Male       Sports and travel       86.31
# ..           ...        ...     ...                     ...         ...
# 995  233-67-5758  Naypyitaw    Male       Health and beauty       40.35
# 996  303-96-2227   Mandalay  Female      Home and lifestyle       97.38
# 997  727-02-1313     Yangon    Male      Food and beverages       31.84
# 998  347-56-2442     Yangon    Male      Home and lifestyle       65.82
# 999  849-09-3807     Yangon  Female     Fashion accessories       88.34
#
#      Quantity    Total        Date      Payment  gross income  Rating  \
# ...

# %%
df["Invoice ID"] = df["Invoice ID"].astype(str).str.replace("-", "", regex=True)

# %%
print(df.head())
# Out:
#   Invoice ID       City  Gender            Product line  Unit price  Quantity  \
# 0  750678428     Yangon  Female       Health and beauty       74.69         7
# 1  226313081  Naypyitaw  Female  Electronic accessories       15.28         5
# 2  631413108     Yangon    Male      Home and lifestyle       46.33         7
# 3  123191176     Yangon    Male       Health and beauty       58.22         8
# 4  373737910     Yangon    Male       Sports and travel       86.31         7
#
#     Total        Date      Payment  gross income  Rating  \
# 0  548.97  2019-01-05      Ewallet       26.1415     9.1
# 1   80.22  2019-03-08         Cash        3.8200     9.6
# 2  340.53  2019-03-03  Credit card       16.2155     7.4
# 3  489.05  2019-01-27      Ewallet       23.2880     8.4
# 4  634.38  2019-02-08      Ewallet       30.2085     5.3
#
#    Calculated Gross Income
# 0                    27.45
# 1                     4.01
# 2                    17.03
# 3                    24.45
# ...

# %%
df['Gender'] = df['Gender'].apply(lambda x: 0 if x == 'Male' else 1)

print(df)
# Out:
#     Invoice ID       City  Gender            Product line  Unit price  \
# 0    750678428     Yangon       1       Health and beauty       74.69
# 1    226313081  Naypyitaw       1  Electronic accessories       15.28
# 2    631413108     Yangon       0      Home and lifestyle       46.33
# 3    123191176     Yangon       0       Health and beauty       58.22
# 4    373737910     Yangon       0       Sports and travel       86.31
# ..         ...        ...     ...                     ...         ...
# 995  233675758  Naypyitaw       0       Health and beauty       40.35
# 996  303962227   Mandalay       1      Home and lifestyle       97.38
# 997  727021313     Yangon       0      Food and beverages       31.84
# 998  347562442     Yangon       0      Home and lifestyle       65.82
# 999  849093807     Yangon       1     Fashion accessories       88.34
#
#      Quantity    Total        Date      Payment  gross income  Rating  \
# ...

# %%
df.head()
# Out:
#   Invoice ID       City  Gender            Product line  Unit price  Quantity  \
# 0  750678428     Yangon       1       Health and beauty       74.69         7
# 1  226313081  Naypyitaw       1  Electronic accessories       15.28         5
# 2  631413108     Yangon       0      Home and lifestyle       46.33         7
# 3  123191176     Yangon       0       Health and beauty       58.22         8
# 4  373737910     Yangon       0       Sports and travel       86.31         7
#
#     Total        Date      Payment  gross income  Rating  \
# 0  548.97  2019-01-05      Ewallet       26.1415     9.1
# 1   80.22  2019-03-08         Cash        3.8200     9.6
# 2  340.53  2019-03-03  Credit card       16.2155     7.4
# 3  489.05  2019-01-27      Ewallet       23.2880     8.4
# 4  634.38  2019-02-08      Ewallet       30.2085     5.3
#
#    Calculated Gross Income
# 0                    27.45
# 1                     4.01
# 2                    17.03
# 3                    24.45
# ...

# %%
df['Product line'] = df['Product line'].str.strip().str.lower().str.replace(' ', '_')
df['Payment'] = df['Payment'].str.strip().str.lower().str.replace(' ', '_')

# %%
# !pip install transformers
# !pip install datasets
# !pip install pandas
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %%
import pandas as pd

df = pd.read_csv("input_table.csv")
df.head()
# Out:
#     Invoice ID       City  Gender            Product line  Unit price  \
# 0  750-67-8428     Yangon  Female       Health and beauty       74.69
# 1  226-31-3081  Naypyitaw  Female  Electronic accessories       15.28
# 2  631-41-3108     Yangon    Male      Home and lifestyle       46.33
# 3  123-19-1176     Yangon    Male       Health and beauty       58.22
# 4  373-73-7910     Yangon    Male       Sports and travel       86.31
#
#    Quantity     Total       Date      Payment  gross income  Rating
# 0         7  548.9715   1/5/2019      Ewallet       26.1415     9.1
# 1         5   80.2200   3/8/2019         Cash        3.8200     9.6
# 2         7  340.5255   3/3/2019  Credit card       16.2155     7.4
# 3         8  489.0480  1/27/2019      Ewallet       23.2880     8.4
# 4         7  634.3785   2/8/2019      Ewallet       30.2085     5.3

# %%
from sentence_transformers import SentenceTransformer

# Load a pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')  # lightweight and fast

# Create embeddings for each row (combine relevant fields)
df['combined_text'] = df.apply(lambda row: f"{row['Product line']} {row['gross income']}", axis=1)
df['embedding'] = df['combined_text'].apply(lambda x: model.encode(x))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Example Query
query = "What is the highest gross income for health and beauty product line?"
query_embedding = model.encode(query)

# Compute similarity
df['similarity'] = df['embedding'].apply(lambda x: cosine_similarity([x], [query_embedding])[0][0])

# Get top N relevant rows
top_n = df.sort_values(by='similarity', ascending=False).head(5)
top_n[['Product line', 'gross income', 'similarity']]
# Out:
#           Product line  gross income  similarity
# 668  Health and beauty       14.3130    0.626447
# 776  Health and beauty       22.8585    0.588269
# 808  Health and beauty        0.8875    0.585420
# 398  Health and beauty       12.3180    0.584310
# 678  Health and beauty       29.4750    0.581582

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

prompt = "What is the average gross income for electronic accessories?"  # <-- Add this!

# Tokenize
inputs = tokenizer(prompt, return_tensors="pt")
print("Input Token IDs:", inputs['input_ids'])

# Generate output token IDs
outputs = model.generate(**inputs)
print("Output Token IDs:", outputs)

# Decode output tokens to string
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("Final Output:", decoded)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import pandas as pd

# Load question sheet
df = pd.read_excel("myquery.xlsx")

# Load FLAN-T5 model
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

generated_responses = []

# For each question, generate response
for q in df["question"]:
    inputs = tokenizer(q, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=100)
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    generated_responses.append(decoded)

# Add to dataframe
df["generated response"] = generated_responses

# ✅ Overwrite original file with generated responses
df.to_excel("myquery.xlsx", index=False)

print("✅ Done! Check 'myquery.xlsx' for the results.")
# Out:
# ✅ Done! Check 'myquery.xlsx' for the results.

# %%
df = pd.read_excel("myquery.xlsx")
df.head()
# Out:
#                                             question  \
# 0          What product line is in the latest entry?
# 1      On what date did the first transaction occur?
# 2               What is the latest transaction date?
# 3  what is the max rating given in home and lifes...
# 4  How many transactions involved Male customers ...
#
#                                            row index column index  \
# 0                                                999            3
# 1  17, 245, 450, 484, 496, 523, 567, 696, 829, 83...            7
# 2  158, 306, 473, 474, 643, 646, 671, 881, 883, 9...            7
# 3  2, 7, 19, 22, 25, 39, 40, 41, 54, 56, 58, 61, ...         3,10
# 4                            331, 464, 540, 708, 710         2,10
#
#                 answer  filtered row index  filtered column index  \
# 0  Fashion accessories                 NaN                    NaN
# 1             1/1/2019                 NaN                    NaN
# ...

# %%
import pandas as pd

# Load the input table and queries
data_df = pd.read_csv("input_table.csv")
query_df = pd.read_excel("myquery.xlsx")

# Helper function to evaluate each question
def evaluate_query(q):
    q_lower = q.lower()

    try:
        if "latest entry" in q_lower and "product line" in q_lower:
            return data_df.iloc[-1]["Product line"]

        elif "first transaction" in q_lower:
            return data_df["Date"].min()

        elif "latest transaction" in q_lower:
            return data_df["Date"].max()

        elif "max rating" in q_lower and "home and lifestyle" in q_lower:
            filtered = data_df[data_df["Product line"].str.lower() == "home and lifestyle"]
            return filtered["Rating"].max()

        elif "male customers" in q_lower and "fashion accessories" in q_lower:
            filtered = data_df[(data_df["Gender"] == "Male") & (data_df["Product line"] == "Fashion accessories")]
            return len(filtered)

        elif "average gross income" in q_lower and "electronic accessories" in q_lower:
            filtered = data_df[data_df["Product line"] == "Electronic accessories"]
            return round(filtered["gross income"].mean(), 2)

        # Add more conditions as needed...

        else:
            return "Not handled"

    except Exception as e:
        return f"Error: {e}"

# Apply function to each question
query_df["evaluated answer"] = query_df["question"].apply(evaluate_query)

# Save the updated file
query_df.to_excel("myquery.xlsx", index=False)
print("✅ Done! 'evaluated answer' column added to myquery.xlsx")
# Out:
# ✅ Done! 'evaluated answer' column added to myquery.xlsx

# %%
df = pd.read_excel("myquery.xlsx")
df.head()
# Out:
#                                             question  \
# 0          What product line is in the latest entry?
# 1      On what date did the first transaction occur?
# 2               What is the latest transaction date?
# 3  what is the max rating given in home and lifes...
# 4  How many transactions involved Male customers ...
#
#                                            row index column index  \
# 0                                                999            3
# 1  17, 245, 450, 484, 496, 523, 567, 696, 829, 83...            7
# 2  158, 306, 473, 474, 643, 646, 671, 881, 883, 9...            7
# 3  2, 7, 19, 22, 25, 39, 40, 41, 54, 56, 58, 61, ...         3,10
# 4                            331, 464, 540, 708, 710         2,10
#
#                 answer  filtered row index  filtered column index  \
# 0  Fashion accessories                 NaN                    NaN
# 1             1/1/2019                 NaN                    NaN
# ...

# %%
import pandas as pd

# Load input table and queries
input_df = pd.read_csv("input_table.csv")
query_df = pd.read_excel("myquery.xlsx")

evaluated_answers = []

# Go through each query
for idx, row in query_df.iterrows():
    try:
        # Parse row and column indexes
        row_idxs = [int(i.strip()) for i in str(row['row index']).split(',') if i.strip().isdigit()]
        col_idxs = [int(i.strip()) for i in str(row['column index']).split(',') if i.strip().isdigit()]

        # Handle case 1: single cell lookup
        if len(row_idxs) == 1 and len(col_idxs) == 1:
            evaluated = input_df.iloc[row_idxs[0], col_idxs[0]]

        # Handle case 2: multiple rows and one column (e.g., for max, min, count)
        elif len(row_idxs) > 0 and len(col_idxs) == 1:
            col_data = input_df.iloc[row_idxs, col_idxs[0]]
            # Try to infer logic from question
            q = row['question'].lower()
            if "max" in q:
                evaluated = col_data.max()
            elif "min" in q:
                evaluated = col_data.min()
            elif "average" in q or "mean" in q:
                evaluated = round(col_data.mean(), 2)
            elif "count" in q or "how many" in q:
                evaluated = len(col_data)
            else:
                evaluated = ", ".join(col_data.astype(str).unique())

        # Handle unsupported or complex logic
        else:
            evaluated = "Not handled"

    except Exception as e:
        evaluated = "Error"

    evaluated_answers.append(evaluated)

# Add to the sheet
query_df["evaluated answer"] = evaluated_answers
query_df.to_excel("myquery.xlsx", index=False)
print("✅ Evaluated answers written to 'myquery.xlsx'")
# Out:
# ✅ Evaluated answers written to 'myquery.xlsx'

# %%
df = pd.read_excel("myquery.xlsx")
df.head()
# Out:
#                                             question  \
# 0          What product line is in the latest entry?
# 1      On what date did the first transaction occur?
# 2               What is the latest transaction date?
# 3  what is the max rating given in home and lifes...
# 4  How many transactions involved Male customers ...
#
#                                            row index column index  \
# 0                                                999            3
# 1  17, 245, 450, 484, 496, 523, 567, 696, 829, 83...            7
# 2  158, 306, 473, 474, 643, 646, 671, 881, 883, 9...            7
# 3  2, 7, 19, 22, 25, 39, 40, 41, 54, 56, 58, 61, ...         3,10
# 4                            331, 464, 540, 708, 710         2,10
#
#                 answer  filtered row index  filtered column index  \
# 0  Fashion accessories                 NaN                    NaN
# 1             1/1/2019                 NaN                    NaN
# ...

# %%
def match(generated, evaluated):
    return "Yes" if str(generated).strip().lower() == str(evaluated).strip().lower() else "No"

df["is_match"] = df.apply(lambda row: match(row["generated response"], row["evaluated answer"]), axis=1)
df.to_excel("myquery.xlsx", index=False)
print("✅ Match column added.")
# Out:
# ✅ Match column added.

# %%
df = pd.read_excel("myquery.xlsx")
df.head()
# Out:
#                                             question  \
# 0          What product line is in the latest entry?
# 1      On what date did the first transaction occur?
# 2               What is the latest transaction date?
# 3  what is the max rating given in home and lifes...
# 4  How many transactions involved Male customers ...
#
#                                            row index column index  \
# 0                                                999            3
# 1  17, 245, 450, 484, 496, 523, 567, 696, 829, 83...            7
# 2  158, 306, 473, 474, 643, 646, 671, 881, 883, 9...            7
# 3  2, 7, 19, 22, 25, 39, 40, 41, 54, 56, 58, 61, ...         3,10
# 4                            331, 464, 540, 708, 710         2,10
#
#                 answer  filtered row index  filtered column index  \
# 0  Fashion accessories                 NaN                    NaN
# 1             1/1/2019                 NaN                    NaN
# ...

# %%
correct = (query_df['answer'].astype(str) == query_df['evaluated answer'].astype(str)).sum()
accuracy = correct / len(query_df)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 25.71%
